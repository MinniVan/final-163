# %%
"""
Names: Van Tha Bik Lian
       Evelena Burunova

Date: 8/21
Mentor: Alex

Running the program. Press shift enter
here, and the next box, you will be prompted
by the program
"""

import h5py
import program

# %%
program.main()
# Out:
# In this program we will be exploring a Dense Neural Network (DNN) algorithm for jet tagging in high energy physics. Specifically we will analyze two type of features that would be used as input for the DNN model. We will achieve this by plotting some of these features in a probability denisty of that feature and 5 labels used for supervised learning.
#
# You, the user, will be prompted to decide which level type you are interested in, followed by the features you want to see plotted. There are a total of sixteen high level features and seven total low level features.
#
# There are two files in here
#      1. Big Sample (aprox (1.3GB)
#      2. Smaller Sample (aprox. 500mb)
#
# Specify which sample you would like us to load.
# Choose the file (Type 1 or 2):  2
# Hang in there! We are loading your sample...
#
#
# For your information, here is a count of each jets that are in each truth jet label from your selected sample.
#
#    Label  Number of jets       Description
# ...
